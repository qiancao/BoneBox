# %%
import numpy as np
from bonebox.phantoms.TrabeculaeVoronoi_Shi import *
import ipyvolume as ipv
import nibabel as nib
import random
import math
import os
from tqdm import tqdm

# Parameters for generating phantom mesh
# volume extent in XYZ (mm), number of seeds along XYZ
Sxyz                = (5,5,5)
edgesRetainFraction = 0.5
facesRetainFraction = 0.5
randState           = 123 # for repeatability
# randState           = random.choice(range(100))
volumeSizeVoxels    = (250,250,250)
# Parameters for generating phantom volume
voxelSize           = np.array(Sxyz) / np.array(volumeSizeVoxels)

if not os.path.exists('BoneSet'):
    os.mkdir('BoneSet')

for dilationRadius in [4,5,6,7]:
    for zS in [0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.7,0.9,1.1]:
        for aspect in [1,2,3,4,5,6,7,8]:
            for Rxyz in [0.4]:
                zSt           = zS + dilationRadius * 2 * voxelSize[1]
                Spacingxyz   = (zSt, zSt*aspect, zSt)

                multiplier       = int(np.round(zSt*aspect*5/Sxyz[1],0))
                if multiplier == 0:
                    multiplier = 2
                
                if multiplier == 1:
                    multiplier = 2
                    

                Sxyzt             = (Sxyz[0]*multiplier,Sxyz[1]*multiplier,Sxyz[2]*multiplier)
                volumeSizeVoxelst = (volumeSizeVoxels[0]*multiplier,
                                    volumeSizeVoxels[1]*multiplier,
                                    volumeSizeVoxels[2]*multiplier)

                ################# Generate faces and edges #######################################
                # points = makeSeedPointsCartesian(dx, dy, dz, axy, axz, ayx, ayz, azx, azy, Sxyz)
                points = makeSeedPointsCartesian_LineorArc(Spacingxyz[0], \
                                                           Spacingxyz[1], \
                                                           Spacingxyz[2], \
                                                           0, 0, 0, \
                                                           0, 0, 0, \
                                                           Sxyzt,10000000)

                # Random perturbation
                ppoints = perturbSeedPointsCartesianUniformXYZ(points, Rxyz, randState=randState)

                # Generate voronoi tessilation
                vor, ind = applyVoronoi(ppoints, Sxyzt)

                # Finalize initial edges and faces
                uniqueEdges, uniqueFaces = findUniqueEdgesAndFaces(vor, ind,Sxyzt)
                #################################################################################



                ######################### Filter random edges and faces ########################
                uniqueFacesRetain, facesRetainInd = filterFacesRandomUniform(uniqueFaces, 
                                                                             facesRetainFraction, 
                                                                             randState=randState)
                #################################################################################



                #################### Remove Edge that is part of a face #########################
#                 for j in tqdm(range(len(uniqueFacesRetain))):
#                     temp = [np.sum(np.isin(uniqueEdges[x], uniqueFacesRetain[j]).astype(int)) == 2 for x in range(len(uniqueEdges))]
#                     temp = np.array(temp).astype(int)
#                     if j == 0:
#                         t = temp
#                     else:
#                         t = t + temp
#                 edge = np.delete(uniqueEdges,np.where(t>0)[0].astype(int), axis=0)
                #################################################################################
                edge = uniqueEdges
                #################################################################################




                #################### Randomly Remove Edge #######################################
                uniqueEdgesRetain, edgesRetainInd = filterEdgesRandomUniform(edge, 
                                                                             edgesRetainFraction, 
                                                                             randState=randState)
                #################################################################################




                ####################### PRINT INFO ##############################################
                print("Face number final = %d" % len(facesRetainInd))
                print("Edge number before random removal = %d" % len(edge))
                print("Edge number final = %d\n" % len(edgesRetainInd))
                RodToPlate = len(edge)/len(facesRetainInd)
                print("Max Rod/plate number = %f" % RodToPlate)
                RodToPlate = len(edgesRetainInd)/len(facesRetainInd)
                print("Final Rod/plate number = %f" % RodToPlate)
                #################################################################################




                ############## Generate Volume base on the remaining face and edges #############
                volumeEdges = makeSkeletonVolumeEdges(vor.vertices, 
                                                      uniqueEdgesRetain, 
                                                      voxelSize, 
                                                      volumeSizeVoxelst)
                volumeFaces = makeSkeletonVolumeFaces(vor.vertices, 
                                                      uniqueFacesRetain, 
                                                      voxelSize, 
                                                      volumeSizeVoxelst)
                #################################################################################


                center       = volumeSizeVoxelst[1]/2
                startInd     = int(center-volumeSizeVoxelst[0]/multiplier/2)
                endInd       = int(startInd+volumeSizeVoxelst[0]/multiplier)

                volumeEdges = volumeEdges[startInd:endInd,startInd:endInd,startInd:endInd]
                volumeFaces = volumeFaces[startInd:endInd,startInd:endInd,startInd:endInd]

                volumeDilated = dilateVolumeSphereUniform(np.logical_or(volumeEdges,volumeFaces), \
                                                          dilationRadius)




                ############################### SAVE #############################################
                volumeDilated = volumeDilated * 1;
                ni_img = nib.Nifti1Image(volumeDilated, affine=np.eye(4))
                nib.save(ni_img, os.path.join('BoneSet', 'dilation_' + \
                                                                     str("%0.2f" % (float(dilationRadius)*voxelSize[1]*2)+ \
                                                          '_spacing_' + \
                                                                     str("%0.2f" % zSt)+ \
                                                          '_Disturbance_' + \
                                                                     str("%0.4f" % Rxyz)+ \
                                                          '_aspect_' + \
                                                                     str("%0.0f" % aspect)+ '.nii')))
                #################################################################################
                #################################################################################
# Out:
# Face number final = 27104
# Edge number before random removal = 99247
# Edge number final = 49624
#
# Max Rod/plate number = 3.661710
# Final Rod/plate number = 1.830874
# Face number final = 13502
# Edge number before random removal = 50111
# Edge number final = 25056
#
# Max Rod/plate number = 3.711376
# Final Rod/plate number = 1.855725
# Face number final = 8146
# Edge number before random removal = 30659
# Edge number final = 15330
#
# Max Rod/plate number = 3.763688
# Final Rod/plate number = 1.881905
# Face number final = 5628
# Edge number before random removal = 21329
# Edge number final = 10664
#
# Max Rod/plate number = 3.789801
# Final Rod/plate number = 1.894812
# Face number final = 4804
# Edge number before random removal = 18541
# Edge number final = 9270
#
# Max Rod/plate number = 3.859492
# Final Rod/plate number = 1.929642
# Face number final = 13271
# Edge number before random removal = 49360
# Edge number final = 24680
#
# Max Rod/plate number = 3.719388
# Final Rod/plate number = 1.859694
# Face number final = 11762
# Edge number before random removal = 44762
# Edge number final = 22381
#
# Max Rod/plate number = 3.805645
# Final Rod/plate number = 1.902823
# Face number final = 24150
# Edge number before random removal = 88304
# Edge number final = 44152
#
# Max Rod/plate number = 3.656480
# Final Rod/plate number = 1.828240
# Face number final = 19841
# Edge number before random removal = 72850
# Edge number final = 36425
#
# Max Rod/plate number = 3.671690
# Final Rod/plate number = 1.835845
# Face number final = 9056
# Edge number before random removal = 33790
# Edge number final = 16895
#
# Max Rod/plate number = 3.731228
# Final Rod/plate number = 1.865614
# Face number final = 6314
# Edge number before random removal = 23945
# Edge number final = 11972
#
# Max Rod/plate number = 3.792366
# Final Rod/plate number = 1.896104
# Face number final = 4234
# Edge number before random removal = 16332
# Edge number final = 8166
#
# Max Rod/plate number = 3.857345
# Final Rod/plate number = 1.928673
# Face number final = 10988
# Edge number before random removal = 40710
# Edge number final = 20355
#
# Max Rod/plate number = 3.704951
# Final Rod/plate number = 1.852475
# Face number final = 9950
# Edge number before random removal = 37630
# Edge number final = 18815
#
# Max Rod/plate number = 3.781910
# Final Rod/plate number = 1.890955
# Face number final = 19726
# Edge number before random removal = 72450
# Edge number final = 36225
#
# Max Rod/plate number = 3.672818
# Final Rod/plate number = 1.836409
# Face number final = 18012
# Edge number before random removal = 67434
# Edge number final = 33717
#
# Max Rod/plate number = 3.743837
# Final Rod/plate number = 1.871919
# Face number final = 14474
# Edge number before random removal = 52963
# Edge number final = 26482
#
# Max Rod/plate number = 3.659182
# Final Rod/plate number = 1.829626
# Face number final = 7130
# Edge number before random removal = 26602
# Edge number final = 13301
#
# Max Rod/plate number = 3.730996
# Final Rod/plate number = 1.865498
# Face number final = 3772
# Edge number before random removal = 14286
# Edge number final = 7143
#
# Max Rod/plate number = 3.787381
# Final Rod/plate number = 1.893690
# Face number final = 3326
# Edge number before random removal = 12865
# Edge number final = 6432
#
# Max Rod/plate number = 3.868010
# Final Rod/plate number = 1.933854
# Face number final = 8582
# Edge number before random removal = 32285
# Edge number final = 16142
#
# Max Rod/plate number = 3.761944
# Final Rod/plate number = 1.880914
# Face number final = 7556
# Edge number before random removal = 28948
# Edge number final = 14474
#
# Max Rod/plate number = 3.831128
# Final Rod/plate number = 1.915564
# Face number final = 15198
# Edge number before random removal = 56855
# Edge number final = 28428
#
# Max Rod/plate number = 3.740953
# Final Rod/plate number = 1.870509
# Face number final = 13400
# Edge number before random removal = 50998
# Edge number final = 25499
#
# Max Rod/plate number = 3.805821
# Final Rod/plate number = 1.902910
# Face number final = 10569
# Edge number before random removal = 39526
# Edge number final = 19763
#
# Max Rod/plate number = 3.739805
# Final Rod/plate number = 1.869903
# Face number final = 5797
# Edge number before random removal = 21922
# Edge number final = 10961
#
# Max Rod/plate number = 3.781611
# Final Rod/plate number = 1.890806
# Face number final = 3018
# Edge number before random removal = 11676
# Edge number final = 5838
#
# Max Rod/plate number = 3.868787
# Final Rod/plate number = 1.934394
# Face number final = 2717
# Edge number before random removal = 10613
# Edge number final = 5306
#
# Max Rod/plate number = 3.906146
# Final Rod/plate number = 1.952889
# Face number final = 6818
# Edge number before random removal = 26049
# Edge number final = 13024
#
# Max Rod/plate number = 3.820622
# Final Rod/plate number = 1.910238
# Face number final = 13242
# Edge number before random removal = 49478
# Edge number final = 24739
#
# Max Rod/plate number = 3.736445
# Final Rod/plate number = 1.868222
# Face number final = 11840
# Edge number before random removal = 45166
# Edge number final = 22583
#
# Max Rod/plate number = 3.814696
# Final Rod/plate number = 1.907348
# Face number final = 20252
# Edge number before random removal = 75336
# Edge number final = 37668
#
# Max Rod/plate number = 3.719929
# Final Rod/plate number = 1.859964
# Face number final = 9272
# Edge number before random removal = 34350
# Edge number final = 17175
#
# Max Rod/plate number = 3.704702
# Final Rod/plate number = 1.852351
# Face number final = 3939
# Edge number before random removal = 14996
# Edge number final = 7498
#
# Max Rod/plate number = 3.807058
# Final Rod/plate number = 1.903529
# Face number final = 2520
# Edge number before random removal = 9834
# Edge number final = 4917
#
# Max Rod/plate number = 3.902381
# Final Rod/plate number = 1.951190
# Face number final = 6126
# Edge number before random removal = 23263
# Edge number final = 11632
#
# Max Rod/plate number = 3.797421
# Final Rod/plate number = 1.898792
# Face number final = 5520
# Edge number before random removal = 21334
# Edge number final = 10667
#
# Max Rod/plate number = 3.864855
# Final Rod/plate number = 1.932428
# Face number final = 10638
# Edge number before random removal = 40433
# Edge number final = 20216
#
# Max Rod/plate number = 3.800808
# Final Rod/plate number = 1.900357
# Face number final = 17754
# Edge number before random removal = 65814
# Edge number final = 32907
#
# Max Rod/plate number = 3.706996
# Final Rod/plate number = 1.853498
# Face number final = 15994
# Edge number before random removal = 60505
# Edge number final = 30252
#
# Max Rod/plate number = 3.782981
# Final Rod/plate number = 1.891459
# Face number final = 6430
# Edge number before random removal = 24192
# Edge number final = 12096
#
# Max Rod/plate number = 3.762364
# Final Rod/plate number = 1.881182
# Face number final = 3151
# Edge number before random removal = 12111
# Edge number final = 6056
#
# Max Rod/plate number = 3.843542
# Final Rod/plate number = 1.921930
# Face number final = 2076
# Edge number before random removal = 8183
# Edge number final = 4092
#
# Max Rod/plate number = 3.941715
# Final Rod/plate number = 1.971098
# Face number final = 5084
# Edge number before random removal = 19544
# Edge number final = 9772
#
# Max Rod/plate number = 3.844217
# Final Rod/plate number = 1.922109
# Face number final = 9636
# Edge number before random removal = 36377
# Edge number final = 18188
#
# Max Rod/plate number = 3.775114
# Final Rod/plate number = 1.887505
# Face number final = 8695
# Edge number before random removal = 33383
# Edge number final = 16692
#
# Max Rod/plate number = 3.839333
# Final Rod/plate number = 1.919724
# Face number final = 14361
# Edge number before random removal = 54224
# Edge number final = 27112
#
# Max Rod/plate number = 3.775782
# Final Rod/plate number = 1.887891
# Face number final = 21864
# Edge number before random removal = 81094
# Edge number final = 40547
#
# Max Rod/plate number = 3.709019
# Final Rod/plate number = 1.854510
# Face number final = 5993
# Edge number before random removal = 22264
# Edge number final = 11132
#
# Max Rod/plate number = 3.715001
# Final Rod/plate number = 1.857500
# Face number final = 2880
# Edge number before random removal = 10996
# Edge number final = 5498
#
# Max Rod/plate number = 3.818056
# Final Rod/plate number = 1.909028
# Face number final = 1787
# Edge number before random removal = 6994
# Edge number final = 3497
#
# Max Rod/plate number = 3.913822
# Final Rod/plate number = 1.956911
# Face number final = 4300
# Edge number before random removal = 16607
# Edge number final = 8304
#
# Max Rod/plate number = 3.862093
# Final Rod/plate number = 1.931163
# Face number final = 8098
# Edge number before random removal = 30780
# Edge number final = 15390
#
# Max Rod/plate number = 3.800939
# Final Rod/plate number = 1.900469
# Face number final = 13191
# Edge number before random removal = 49510
# Edge number final = 24755
#
# Max Rod/plate number = 3.753317
# Final Rod/plate number = 1.876658
# Face number final = 12020
# Edge number before random removal = 45878
# Edge number final = 22939
#
# Max Rod/plate number = 3.816805
# Final Rod/plate number = 1.908403
# Face number final = 18017
# Edge number before random removal = 67914
# Edge number final = 33957
#
# Max Rod/plate number = 3.769440
# Final Rod/plate number = 1.884720
# Face number final = 3488
# Edge number before random removal = 13092
# Edge number final = 6546
#
# Max Rod/plate number = 3.753440
# Final Rod/plate number = 1.876720
# Face number final = 1372
# Edge number before random removal = 5352
# Edge number final = 2676
#
# Max Rod/plate number = 3.900875
# Final Rod/plate number = 1.950437
# Face number final = 3552
# Edge number before random removal = 13632
# Edge number final = 6816
#
# Max Rod/plate number = 3.837838
# Final Rod/plate number = 1.918919
# Face number final = 3300
# Edge number before random removal = 12773
# Edge number final = 6386
#
# Max Rod/plate number = 3.870606
# Final Rod/plate number = 1.935152
# Face number final = 5837
# Edge number before random removal = 22585
# Edge number final = 11292
#
# Max Rod/plate number = 3.869282
# Final Rod/plate number = 1.934555
# Face number final = 9491
# Edge number before random removal = 36184
# Edge number final = 18092
#
# Max Rod/plate number = 3.812454
# Final Rod/plate number = 1.906227
# Face number final = 13885
# Edge number before random removal = 52698
# Edge number final = 26349
#
# Max Rod/plate number = 3.795319
# Final Rod/plate number = 1.897659
# Face number final = 19408
# Edge number before random removal = 72964
# Edge number final = 36482
#
# Max Rod/plate number = 3.759481
# Final Rod/plate number = 1.879740
# Face number final = 1744
# Edge number before random removal = 6673
# Edge number final = 3336
#
# Max Rod/plate number = 3.826261
# Final Rod/plate number = 1.912844
# Face number final = 823
# Edge number before random removal = 3250
# Edge number final = 1625
#
# Max Rod/plate number = 3.948967
# Final Rod/plate number = 1.974484
# Face number final = 2051
# Edge number before random removal = 8083
# Edge number final = 4042
#
# Max Rod/plate number = 3.941004
# Final Rod/plate number = 1.970746
# Face number final = 3820
# Edge number before random removal = 14905
# Edge number final = 7452
#
# Max Rod/plate number = 3.901832
# Final Rod/plate number = 1.950785
# Face number final = 6090
# Edge number before random removal = 23578
# Edge number final = 11789
#
# Max Rod/plate number = 3.871593
# Final Rod/plate number = 1.935796
# Face number final = 8950
# Edge number before random removal = 34306
# Edge number final = 17153
#
# Max Rod/plate number = 3.833073
# Final Rod/plate number = 1.916536
# Face number final = 12250
# Edge number before random removal = 46723
# Edge number final = 23362
#
# Max Rod/plate number = 3.814122
# Final Rod/plate number = 1.907102
# Face number final = 15984
# Edge number before random removal = 60724
# Edge number final = 30362
#
# Max Rod/plate number = 3.799049
# Final Rod/plate number = 1.899525
# Face number final = 730
# Edge number before random removal = 2882
# Edge number final = 1441
#
# Max Rod/plate number = 3.947945
# Final Rod/plate number = 1.973973
# Face number final = 1376
# Edge number before random removal = 5374
# Edge number final = 2687
#
# Max Rod/plate number = 3.905523
# Final Rod/plate number = 1.952762
# Face number final = 2698
# Edge number before random removal = 10392
# Edge number final = 5196
#
# Max Rod/plate number = 3.851742
# Final Rod/plate number = 1.925871
# Face number final = 4422
# Edge number before random removal = 16954
# Edge number final = 8477
#
# Max Rod/plate number = 3.834012
# Final Rod/plate number = 1.917006
# Face number final = 6300
# Edge number before random removal = 24264
# Edge number final = 12132
#
# Max Rod/plate number = 3.851429
# Final Rod/plate number = 1.925714
# Face number final = 11520
# Edge number before random removal = 43776
# Edge number final = 21888
#
# Max Rod/plate number = 3.800000
# Final Rod/plate number = 1.900000
# Face number final = 14701
# Edge number before random removal = 55682
# Edge number final = 27841
#
# Max Rod/plate number = 3.787633
# Final Rod/plate number = 1.893817
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [1], in <cell line: 24>()
#     106 #################################################################################
#     107
#     108
#     109
#     110
#     111 ############## Generate Volume base on the remaining face and edges #############
#     112 volumeEdges = makeSkeletonVolumeEdges(vor.vertices,
#     113                                       uniqueEdgesRetain,
#     114                                       voxelSize,
#     115                                       volumeSizeVoxelst)
# --> 116 volumeFaces = makeSkeletonVolumeFaces(vor.vertices,
#     117                                       uniqueFacesRetain,
#     118                                       voxelSize,
#     119                                       volumeSizeVoxelst)
#     120 #################################################################################
#     123 center       = volumeSizeVoxelst[1]/2
#
# File D:\d_users\Research\BoneBox\bonebox\phantoms\TrabeculaeVoronoi_Shi.py:766, in makeSkeletonVolumeFaces(vertices, faceInds, voxelSize, volumeSizeVoxels, values)
#     763 verticesArray = convertAbs2Array(vertices, voxelSize, volumeSizeVoxels)
#     765 # invoke drawFace
# --> 766 drawFace(volume, verticesArray, faceInds)
#     768 return volume
#
# File D:\d_users\Research\BoneBox\bonebox\phantoms\TrabeculaeVoronoi_Shi.py:722, in drawFace(volume, verticesArray, faceVertexInd)
#     719     surf = tuple(np.array(list(surf)).T) # convert from set of points to tuple of XYZ coordinates
#     720     volume[surf] = 1
# --> 722 volume = (volume>0).astype(int)
#     724 return volume
#
# MemoryError: Unable to allocate 42.4 GiB for an array with shape (2250, 2250, 2250) and data type int32
